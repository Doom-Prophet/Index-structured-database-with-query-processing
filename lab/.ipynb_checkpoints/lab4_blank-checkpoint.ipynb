# %% [markdown]
# # CS225 Discussion 4
# ## Exercise 1
#
# (i) Explore the various sorting methods on the class *HashSet* deﬁned in the lectures.
#
# (ii) Extend the class *HashSet* by methods for checking of equality of sets or subsets and operations for set union, intersection and difference.
#
# (iii) Modify the class *HashSet* by using parameters for the minimum and maximum load factor (currently set to 0.25 and 0.75).

# %%
# 1.(i)
class HashSet:
    def __init__(self,contents=[]):
        self.items = [None] * 20
        self.numItems = 0
        for e in contents:
            self.add(e)
            
    def add(self,item):
        if HashSet.__add(item,self.items):
            self.numItems += 1
            load = self.numItems / len(self.items)
            if load >= 0.75:
                self.items = HashSet.__rehash(self.items, [None]*2*len(self.items))
                
    def __contains__(self,item):
        index = hash(item) % len(self.items)
        while self.items[index] != None:
            if self.items[index] == item:
                return True
            index = (index + 1) % len(self.items)
        return False
    
    def delete(self,item):
        if HashSet.__remove(item,self.items):
            self.numItems -= 1
            load = max(self.numItems,20) / len(self.items)
            if load <= 0.25:
                self.items = HashSet.__rehash(self.items, [None]*(len(self.items) // 2))
        else:
            raise KeyError("Item not in HashSet")

    # ===== Hidden Class =====
    class __Placeholder:
        def __init__(self):
            pass
        
        def __eq__(self,other):
            return False
    
    # ===== Auxiliary Functions =====
    # They all have '__' as prefixes to indicate that they are private methods to the class
    def __add(item,items):
        index = hash(item) % len(items)
        location = -1
        while items[index] != None:
            if items[index] == item:
                return False
            if location < 0 and type(items[index]) == HashSet.__Placeholder:
                location = index
            index = (index + 1) % len(items)
        if location < 0:
            location = index
        items[location] = item
        return True
        
    def __rehash(olditems,newitems):
        for e in olditems:
            if e != None and type(e) != HashSet.__Placeholder:
                HashSet.__add(e,newitems)
        return newitems
                
    def __remove(item,items):
        index = hash(item) % len(items)
        while items[index] != None:
            if items[index] == item:
                nextIndex = (index + 1) % len(items)
                if items[nextIndex] == None:
                    items[index] = None
                else:
                    items[index] = HashSet.__Placeholder()
                return True
            index = (index + 1) % len(items)
        return False

# %%
## Your Code Here
# Constructor
haha=HashSet([1,2,3,4,10])
print(haha.items)
# Add
haha.add(0)
print(haha.items)
# Delete
haha.delete(2)
print(haha.items)
# Add
haha.add(4)
haha.add(2)
haha.add(7)
print(haha.items)
haha.delete(1)
haha.delete(3)
haha.delete(0)
print(haha.items)
# Out:
# [None, 1, 2, 3, 4, None, None, None, None, None, 10, None, None, None, None, None, None, None, None, None]
# [0, 1, 2, 3, 4, None, None, None, None, None, 10, None, None, None, None, None, None, None, None, None]
# [0, 1, <__main__.HashSet.__Placeholder object at 0x0000026A815E26A0>, 3, 4, None, None, None, None, None, 10, None, None, None, None, None, None, None, None, None]
# [0, 1, 2, 3, 4, None, None, 7, None, None, 10, None, None, None, None, None, None, None, None, None]
# [<__main__.HashSet.__Placeholder object at 0x0000026A81669320>, <__main__.HashSet.__Placeholder object at 0x0000026A81669240>, 2, <__main__.HashSet.__Placeholder object at 0x0000026A815E26A0>, 4, None, None, 7, None, None, 10, None, None, None, None, None, None, None, None, None]

# %%
# 1.(ii)
class HashSet:
    def __init__(self,contents=[]):
        self.items = [None] * 20
        self.numItems = 0
        for e in contents:
            self.add(e)
            
    def add(self,item):
        if HashSet.__add(item,self.items):
            self.numItems += 1
            load = self.numItems / len(self.items)
            if load >= 0.75:
                self.items = HashSet.__rehash(self.items, [None]*2*len(self.items))
                
    def __contains__(self,item):
        index = hash(item) % len(self.items)
        while self.items[index] != None:
            if self.items[index] == item:
                return True
            index = (index + 1) % len(self.items)
        return False
    
    def delete(self,item):
        if HashSet.__remove(item,self.items):
            self.numItems -= 1
            load = max(self.numItems,20) / len(self.items)
            if load <= 0.25:
                self.items = HashSet.__rehash(self.items, [None]*(len(self.items) // 2))
        else:
            raise KeyError("Item not in HashSet")
    
    # Define your new functions here
    def __eq__(self, other):
        ## Your Code Here
        pass
    def union(self, other):
        ## Your Code Here
        pass
    def intersection(self, other):
        ## Your Code Here
        pass
    def difference(self, other):
        ## Your Code Here
        pass
    # ===== Hidden Class =====
    class __Placeholder:
        def __init__(self):
            pass
        
        def __eq__(self,other):
            return False
    
    # ===== Auxiliary Functions =====
    # They all have '__' as prefixes to indicate that they are private methods to the class
    def __add(item,items):
        index = hash(item) % len(items)
        location = -1
        while items[index] != None:
            if items[index] == item:
                return False
            if location < 0 and type(items[index]) == HashSet.__Placeholder:
                location = index
            index = (index + 1) % len(items)
        if location < 0:
            location = index
        items[location] = item
        return True
        
    def __rehash(olditems,newitems):
        for e in olditems:
            if e != None and type(e) != HashSet.__Placeholder:
                HashSet.__add(e,newitems)
        return newitems
                
    def __remove(item,items):
        index = hash(item) % len(items)
        while items[index] != None:
            if items[index] == item:
                nextIndex = (index + 1) % len(items)
                if items[nextIndex] == None:
                    items[index] = None
                else:
                    items[index] = HashSet.__Placeholder()
                return True
            index = (index + 1) % len(items)
        return False

# %%
## Test Your Functions Here
# Check for equality

# %%
## Test Your Code Here
# Set operations

# Union

# Intersection

# Difference

# %%
# 1.(iii)
class HashSet:
    def __init__(self,contents=[]): # add more parameters
        self.items = [None] * 20
        self.numItems = 0
        # Add Load Factor Here
        for e in contents:
            self.add(e)
            
    def add(self,item):
        ## Your Modified Code Here
        pass
                
    def __contains__(self,item):
        index = hash(item) % len(self.items)
        while self.items[index] != None:
            if self.items[index] == item:
                return True
            index = (index + 1) % len(self.items)
        return False
    
    def delete(self,item):
        ## Your Modified Code Here
        pass
    
    ## This Part You should Complete in (ii)
    def __eq__(self, other):
        ## Your Code Here
        pass
    
    def union(self, other):
        ## Your Code Here
        pass
    
    def intersection(self, other):
        ## Your Code Here
        pass
    
    def difference(self, other):
        ## Your Code Here
        pass

    # ===== Hidden Class =====
    class __Placeholder:
        def __init__(self):
            pass
        
        def __eq__(self,other):
            return False
    
    # ===== Auxiliary Functions =====
    # They all have '__' as prefixes to indicate that they are private methods to the class
    def __add(item,items):
        index = hash(item) % len(items)
        location = -1
        while items[index] != None:
            if items[index] == item:
                return False
            if location < 0 and type(items[index]) == HashSet.__Placeholder:
                location = index
            index = (index + 1) % len(items)
        if location < 0:
            location = index
        items[location] = item
        return True
        
    def __rehash(olditems,newitems):
        for e in olditems:
            if e != None and type(e) != HashSet.__Placeholder:
                HashSet.__add(e,newitems)
        return newitems
                
    def __remove(item,items):
        index = hash(item) % len(items)
        while items[index] != None:
            if items[index] == item:
                nextIndex = (index + 1) % len(items)
                if items[nextIndex] == None:
                    items[index] = None
                else:
                    items[index] = HashSet.__Placeholder()
                return True
            index = (index + 1) % len(items)
        return False

# %%
## Your Test Here for Load Factors Actually Works

# %% [markdown]
# ## Exercise 2
#
# (i) Modify the class *HashSet* such that hashing with chaining is used instead of linear probing.
#
# (ii) Explore the deﬁnition of further set operations (as in Exercise 1(ii) above) on this modified implementation of hashsets.

# %%
# 2.(i)
class HashSetChaining:
    ## Your Code Here
    def __init__(self,contents=[]):
        self.items = [None] * 20
        self.numItems = 0
        for e in contents:
            self.add(e)
            
    def add(self,item):
        if HashSet.__add(item,self.items):
            self.numItems += 1
            load = self.numItems / len(self.items)
            if load >= 0.75:
                self.items = HashSet.__rehash(self.items, [None]*2*len(self.items))
                
    def __contains__(self,item):
        index = hash(item) % len(self.items)
        while self.items[index] != None:
            if self.items[index] == item:
                return True
            index = (index + 1) % len(self.items)
        return False
    
    def delete(self,item):
        if HashSet.__remove(item,self.items):
            self.numItems -= 1
            load = max(self.numItems,20) / len(self.items)
            if load <= 0.25:
                self.items = HashSet.__rehash(self.items, [None]*(len(self.items) // 2))
        else:
            raise KeyError("Item not in HashSet")

    # ===== Hidden Class =====
    class __Placeholder:
        def __init__(self):
            pass
        
        def __eq__(self,other):
            return False
    
    # ===== Auxiliary Functions =====
    # They all have '__' as prefixes to indicate that they are private methods to the class
    def __add(item,items):
        index = hash(item) % len(items)
        if items[index] == None:
            items[index] = []
        if item in items[index]:
            return False
        items[index].append(item)
        return True
        
    def __rehash(olditems,newitems):
        for chain in olditems:
            if chain != None
                for e in chain:
                    HashSet.__add(e,newitems)
        return newitems
                
    def __remove(item,items):
        index = hash(item) % len(items)
        if item in items[index]:
            items[index].remove(item)
            if items[index]==[]
                items[index]=None
            return True
        return False

    # you could paste the code for exercise 1 and make some modifications
    pass

# %%
## Your Test Here

# Constructor

# Add

# Delete

# %%
# 2.(ii)
class HashSetChaining:
    ## Your Code Here
    # you could paste the code for exercise 2 (ii) and add some methods
    pass

# %%
## Your Tests Here

# Equality

# %%
# Set operations
# Union

# Intersection

# Difference

# %% [markdown]
# ## Exercise 3
#
# A map $M$ is a partial function that is depend on a set $K$, i.e. we can write $M$ as a set of key-value pairs $(k,v)$ with unique keys $k \in K$. Memoisation is a programming technique useful for cases, where the same call of a function is used multiple times. In order to avoid costly recomputation it uses a map to store results from previous calls.
#
# (i) Define a class *HashMap* in analogy to *HashSet* to represent maps. As keys uniquely determine key-value pairs let the hash values only depend on the keys of such pairs.
#
# (ii) Use your class *HashMap* for memoisation on an example of your choice—you could use a naive algorithm for computing Fibonacci numbers, the towers of Hanoi problem, or just the location of elements on a given position in a doublylinked list.
#
# **Note.** Such a class *HashMap* is discussed in the textbook by Lee/Hubbard in Section 5.7 (page 153 ﬀ.).
#
# ##### ------- Tips --------
# To get access to this book and class implementation, you could use this [link](https://kentdlee.github.io/CS2Plus/build/html/index.html)
# or download the whole book in [google drive](https://drive.google.com/file/d/0B5W_rrjzIULTNEJyblAwZlhTaHc/view).

# %%
# 3.(i)
## Modify the code for HashSet in class if needed
class HashSet:
    def __init__(self,contents=[]):
        self.items = [None] * 20
        self.numItems = 0
        for e in contents:
            self.add(e)
            
    def add(self,item):
        if HashSet.__add(item,self.items):
            self.numItems += 1
            load = self.numItems / len(self.items)
            if load >= 0.75:
                self.items = HashSet.__rehash(self.items, [None]*2*len(self.items))
                
    def __contains__(self,item):
        index = hash(item) % len(self.items)
        while self.items[index] != None:
            if self.items[index] == item:
                return True
            index = (index + 1) % len(self.items)
        return False
    
    def delete(self,item):
        if HashSet.__remove(item,self.items):
            self.numItems -= 1
            load = max(self.numItems,20) / len(self.items)
            if load <= 0.25:
                self.items = HashSet.__rehash(self.items, [None]*(len(self.items) // 2))
        else:
            raise KeyError("Item not in HashSet")

    # ===== Hidden Class =====
    class __Placeholder:
        def __init__(self):
            pass
        
        def __eq__(self,other):
            return False
    
    # ===== Auxiliary Functions =====
    # They all have '__' as prefixes to indicate that they are private methods to the class
    def __add(item,items):
        index = hash(item) % len(items)
        location = -1
        while items[index] != None:
            if items[index] == item:
                return False
            if location < 0 and type(items[index]) == HashSet.__Placeholder:
                location = index
            index = (index + 1) % len(items)
        if location < 0:
            location = index
        items[location] = item
        return True
        
    def __rehash(olditems,newitems):
        for e in olditems:
            if e != None and type(e) != HashSet.__Placeholder:
                HashSet.__add(e,newitems)
        return newitems
                
    def __remove(item,items):
        index = hash(item) % len(items)
        while items[index] != None:
            if items[index] == item:
                nextIndex = (index + 1) % len(items)
                if items[nextIndex] == None:
                    items[index] = None
                else:
                    items[index] = HashSet.__Placeholder()
                return True
            index = (index + 1) % len(items)
        return False

# %%
# 3.(i) 
## Define Your HashMap Class Here
class HashMap:
    ## Your Code Here
    pass

# %%
## Test Your Code Here

# %%
# 3.(ii)
## Design Your Memoisation Example Here

# Compare the time usage
